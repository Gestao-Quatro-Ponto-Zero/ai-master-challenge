# %%
import sys
sys.path.insert(0, '.')
import pandas as pd
import numpy as np
from lib.db import *
from lib.classify import *

# %% [markdown]
# # Ticket Classification with LLM
#
# Designing taxonomy, benchmarking models, running classification.
#
# **Strategy:**
# 1. Cluster sample tickets to discover natural categories
# 2. Benchmark models on Dataset 2 (48K labeled tickets = ground truth)
# 3. Apply winning model to Dataset 1 (30K support tickets)

# %%
# Classification logic will go here

# %% [markdown]
# ## Classification Results
#
# _To be filled_
