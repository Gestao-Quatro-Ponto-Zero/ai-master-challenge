# %%
import sys
sys.path.insert(0, '.')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from lib.db import *

sns.set_theme(style='whitegrid')

# %% [markdown]
# # Bottleneck Analysis
#
# Quantifying time and cost impact of each problem identified.
#
# **Framework:**
# - Manual work (high time, low automation)
# - No standard process (high variance)
# - No guided system (misclassification, wrong routing)
# - No integration (channel-specific delays)
#
# **Formula:** Impact = Time_per_occurrence × Frequency × Agent_cost_per_hour

# %%
# Bottleneck analysis queries will go here

# %% [markdown]
# ## Bottleneck Ranking
#
# _To be filled_
