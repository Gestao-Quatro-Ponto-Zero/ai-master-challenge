# %%
import sys
sys.path.insert(0, '.')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from lib.db import *

sns.set_theme(style='whitegrid')

# %% [markdown]
# # Process Mapping
#
# Inferring the as-is support process from data patterns.
#
# **Goal:** Map how tickets flow through the system — channels, routing, escalation, resolution.
#
# We'll look for:
# - Channel → status transitions
# - Priority assignment patterns
# - Resolution patterns by type
# - Time spent at each stage

# %%
# Process analysis queries will go here

# %% [markdown]
# ## Process Observations
#
# _To be filled_
